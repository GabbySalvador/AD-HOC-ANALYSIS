# %%
import pandas as pd
import datetime
import json

# %%
with open('transaction-data-adhoc-analysis.json','r') as f:
    data=json.load(f)

# %%
transactionsdf=pd.DataFrame(data)

# %%
transactionsdf
# Out:
#                                                  address   birthdate  \
# 0                              USNS Wagner\nFPO AE 00917  1926/03/11
# 1                             USCGC Benson\nFPO AP 48794  2016/07/08
# 2                             USCGC Benson\nFPO AP 48794  2016/07/08
# 3                             USCGC Benson\nFPO AP 48794  2016/07/08
# 4               33911 Hansen Loaf\nWest Sandra, ND 54188  1949/09/27
# ...                                                  ...         ...
# 83031      96081 Harrison Brooks\nJenniferbury, MA 02124  2019/10/26
# 83032  428 Kristopher Curve Apt. 206\nMcculloughville...  1913/11/04
# 83033  428 Kristopher Curve Apt. 206\nMcculloughville...  1913/11/04
# 83034  428 Kristopher Curve Apt. 206\nMcculloughville...  1913/11/04
# 83035                   PSC 1089, Box 3720\nAPO AE 08973  2012/04/30
#
#                             mail               name sex       username  \
# ...

# %%
transactionsdf['month'] = pd.DatetimeIndex(transactionsdf['transaction_date']).month

# %%
transactionsdf
# Out:
#                                                  address   birthdate  \
# 0                              USNS Wagner\nFPO AE 00917  1926/03/11
# 1                             USCGC Benson\nFPO AP 48794  2016/07/08
# 2                             USCGC Benson\nFPO AP 48794  2016/07/08
# 3                             USCGC Benson\nFPO AP 48794  2016/07/08
# 4               33911 Hansen Loaf\nWest Sandra, ND 54188  1949/09/27
# ...                                                  ...         ...
# 83031      96081 Harrison Brooks\nJenniferbury, MA 02124  2019/10/26
# 83032  428 Kristopher Curve Apt. 206\nMcculloughville...  1913/11/04
# 83033  428 Kristopher Curve Apt. 206\nMcculloughville...  1913/11/04
# 83034  428 Kristopher Curve Apt. 206\nMcculloughville...  1913/11/04
# 83035                   PSC 1089, Box 3720\nAPO AE 08973  2012/04/30
#
#                             mail               name sex       username  \
# ...

# %%
gender_per_month_df=transactionsdf[["sex","month"]]

# %%
gender_per_month_df
# Out:
#       sex  month
# 0       F      1
# 1       F      1
# 2       F      1
# 3       F      1
# 4       F      1
# ...    ..    ...
# 83031   F      6
# 83032   M      6
# 83033   M      6
# 83034   M      6
# 83035   F      6
#
# [83036 rows x 2 columns]

# %%
gender_gb=gender_per_month_df.groupby("sex")

# %%
gender_gb["sex"].count()
# Out:
# sex
# F    41173
# M    41863
# Name: sex, dtype: int64

# %%
gender_per_month_df["sex"].str.contains("M")
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 83031    False
# 83032     True
# 83033     True
# 83034     True
# 83035    False
# Name: sex, Length: 83036, dtype: bool

# %%
gender_per_month_df["Male"]=gender_per_month_df["sex"].str.contains("M")
# Out:
# /var/folders/n1/vl98150x7gz4l5g4l74pjhqh0000gn/T/ipykernel_1331/816195055.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gender_per_month_df["Male"]=gender_per_month_df["sex"].str.contains("M")

# %%
gender_per_month_df["Female"]=gender_per_month_df["sex"].str.contains("F")
# Out:
# /var/folders/n1/vl98150x7gz4l5g4l74pjhqh0000gn/T/ipykernel_1331/2241178022.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gender_per_month_df["Female"]=gender_per_month_df["sex"].str.contains("F")

# %%
gender_per_month_df
# Out:
#       sex  month   Male  Female
# 0       F      1  False    True
# 1       F      1  False    True
# 2       F      1  False    True
# 3       F      1  False    True
# 4       F      1  False    True
# ...    ..    ...    ...     ...
# 83031   F      6  False    True
# 83032   M      6   True   False
# 83033   M      6   True   False
# 83034   M      6   True   False
# 83035   F      6  False    True
#
# [83036 rows x 4 columns]

# %%
trial_table_3=gender_per_month_df[["sex","month","Female"]]

# %%
trial_table_4=gender_per_month_df[["sex","month","Male"]]

# %%
trial_table_3
# Out:
#       sex  month  Female
# 0       F      1    True
# 1       F      1    True
# 2       F      1    True
# 3       F      1    True
# 4       F      1    True
# ...    ..    ...     ...
# 83031   F      6    True
# 83032   M      6   False
# 83033   M      6   False
# 83034   M      6   False
# 83035   F      6    True
#
# [83036 rows x 3 columns]

# %%
trial_table_3.rename(columns = {"Female":"Stats"}, inplace = True)
# Out:
# /Users/salvadorfamily/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
trial_table_4
# Out:
#       sex  month   Male
# 0       F      1  False
# 1       F      1  False
# 2       F      1  False
# 3       F      1  False
# 4       F      1  False
# ...    ..    ...    ...
# 83031   F      6  False
# 83032   M      6   True
# 83033   M      6   True
# 83034   M      6   True
# 83035   F      6  False
#
# [83036 rows x 3 columns]

# %%
trial_table_4.rename(columns = {"Male":"Stats"}, inplace = True)
# Out:
# /Users/salvadorfamily/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
trial_table_3
# Out:
#       sex  month  Stats
# 0       F      1   True
# 1       F      1   True
# 2       F      1   True
# 3       F      1   True
# 4       F      1   True
# ...    ..    ...    ...
# 83031   F      6   True
# 83032   M      6  False
# 83033   M      6  False
# 83034   M      6  False
# 83035   F      6   True
#
# [83036 rows x 3 columns]

# %%
trial_table_4
# Out:
#       sex  month  Stats
# 0       F      1  False
# 1       F      1  False
# 2       F      1  False
# 3       F      1  False
# 4       F      1  False
# ...    ..    ...    ...
# 83031   F      6  False
# 83032   M      6   True
# 83033   M      6   True
# 83034   M      6   True
# 83035   F      6  False
#
# [83036 rows x 3 columns]

# %%
trial_table_1=pandas.pivot_table(trial_table_3, values=["Stats"], index=["sex"], columns="month", aggfunc='sum', fill_value=None, margins=False, dropna=True, margins_name='All', observed=False)

# %%
trial_table_2=pandas.pivot_table(trial_table_4, values=["Stats"], index=["sex"], columns="month", aggfunc='sum', fill_value=None, margins=False, dropna=True, margins_name='All', observed=False)

# %%
trial_table_1
# Out:
#       Stats
# month     1     2     3     4     5     6
# sex
# F      6796  7006  6841  6851  6850  6829
# M         0     0     0     0     0     0

# %%
trial_table_2
# Out:
#       Stats
# month     1     2     3     4     5     6
# sex
# F         0     0     0     0     0     0
# M      6892  6966  7061  6928  7014  7002

# %%
final_table=trial_table_1+trial_table_2

# %%
final_table #of transactions per month filtered into male and female
# Out:
#       Stats
# month     1     2     3     4     5     6
# sex
# F      6796  7006  6841  6851  6850  6829
# M      6892  6966  7061  6928  7014  7002

# %%
final_table_pie=final_table.reset_index()

# %%
final_table_pie
# Out:
#       sex Stats
# month         1     2     3     4     5     6
# 0       F  6796  7006  6841  6851  6850  6829
# 1       M  6892  6966  7061  6928  7014  7002

# %%
final_table_pie_final=final_table_pie["Stats"]

# %%
final_table_pie_final
# Out:
# month     1     2     3     4     5     6
# 0      6796  7006  6841  6851  6850  6829
# 1      6892  6966  7061  6928  7014  7002

# %%
final_table_pie["sex"]
# Out:
# 0    F
# 1    M
# Name: sex, dtype: object

# %%
final_table_pie_final = final_table_pie_final.assign(Sex=final_table_pie["sex"])

# %%
final_table_pie_final
# Out:
# month     1     2     3     4     5     6 Sex
# 0      6796  7006  6841  6851  6850  6829   F
# 1      6892  6966  7061  6928  7014  7002   M

# %%
list_sex = final_table_pie_final['Sex'].tolist()

# %%
list_sex
# Out:
# ['F', 'M']

# %%
list_m1=final_table_pie_final[1].tolist()
list_m2=final_table_pie_final[2].tolist()
list_m3=final_table_pie_final[3].tolist()
list_m4=final_table_pie_final[4].tolist()
list_m5=final_table_pie_final[5].tolist()
list_m6=final_table_pie_final[6].tolist()

# %%
list_m1
# Out:
# [6796, 6892]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fig = plt.figure(figsize =(10, 7))
plt.pie(list_m1, labels = list_sex,autopct='%1.1f%%')
plt.title('Month 1 Transactions Count (Male vs Female)')
plt.savefig('Month 1 Transactions Count (Male vs Female)', dpi=600, bbox_inches='tight')

# %%
fig = plt.figure(figsize =(10, 7))
plt.pie(list_m2, labels = list_sex,autopct='%1.1f%%')
plt.title('Month 2 Transactions Count (Male vs Female)')
plt.savefig('Month 2 Transactions Count (Male vs Female)', dpi=600, bbox_inches='tight')

# %%
fig = plt.figure(figsize =(10, 7))
plt.pie(list_m3, labels = list_sex,autopct='%1.1f%%')
plt.title('Month 3 Transactions Count (Male vs Female)')
plt.savefig('Month 3 Transactions Count (Male vs Female)', dpi=600, bbox_inches='tight')

# %%
fig = plt.figure(figsize =(10, 7))
plt.pie(list_m4, labels = list_sex,autopct='%1.1f%%')
plt.title('Month 4 Transactions Count (Male vs Female)')
plt.savefig('Month 4 Transactions Count (Male vs Female)', dpi=600, bbox_inches='tight')

# %%
fig = plt.figure(figsize =(10, 7))
plt.pie(list_m5, labels = list_sex,autopct='%1.1f%%')
plt.title('Month 5 Transactions Count (Male vs Female)')
plt.savefig('Month 5 Transactions Count (Male vs Female)', dpi=600, bbox_inches='tight')

# %%
fig = plt.figure(figsize =(10, 7))
plt.pie(list_m6, labels = list_sex,autopct='%1.1f%%')
plt.title('Month 6 Transactions Count (Male vs Female)')
plt.savefig('Month 6 Transactions Count (Male vs Female)', dpi=600, bbox_inches='tight')

# %%
trial_table_3
# Out:
#       sex  month  Stats
# 0       F      1   True
# 1       F      1   True
# 2       F      1   True
# 3       F      1   True
# 4       F      1   True
# ...    ..    ...    ...
# 83031   F      6   True
# 83032   M      6  False
# 83033   M      6  False
# 83034   M      6  False
# 83035   F      6   True
#
# [83036 rows x 3 columns]

# %%
trial_table_4
# Out:
#       sex  month  Stats
# 0       F      1  False
# 1       F      1  False
# 2       F      1  False
# 3       F      1  False
# 4       F      1  False
# ...    ..    ...    ...
# 83031   F      6  False
# 83032   M      6   True
# 83033   M      6   True
# 83034   M      6   True
# 83035   F      6  False
#
# [83036 rows x 3 columns]

# %%
trial_table_3["Sales Value"]=transactionsdf["transaction_value"]

# %%
trial_table_4["Sales Value"]=transactionsdf["transaction_value"]

# %%
trial_table_3
# Out:
#       sex  month  Stats  Sales Value
# 0       F      1   True         5196
# 1       F      1   True        12056
# 2       F      1   True         5500
# 3       F      1   True          500
# 4       F      1   True         2697
# ...    ..    ...    ...          ...
# 83031   F      6   True         3588
# 83032   M      6  False         2095
# 83033   M      6  False         3396
# 83034   M      6  False         4280
# 83035   F      6   True         2639
#
# [83036 rows x 4 columns]

# %%
trial_table_4
# Out:
#       sex  month  Stats  Sales Value
# 0       F      1  False         5196
# 1       F      1  False        12056
# 2       F      1  False         5500
# 3       F      1  False          500
# 4       F      1  False         2697
# ...    ..    ...    ...          ...
# 83031   F      6  False         3588
# 83032   M      6   True         2095
# 83033   M      6   True         3396
# 83034   M      6   True         4280
# 83035   F      6  False         2639
#
# [83036 rows x 4 columns]

# %%
trial_table_1_part2=pd.pivot_table(trial_table_3, values=["Sales Value"], index=["sex"], columns="month", aggfunc='mean', fill_value=None, margins=False, dropna=True, margins_name='All', observed=False)

# %%
trial_table_1_part2  # average (mean) transaction value purchases of each gender per month
# Out:
#        Sales Value                                                      \
# month            1            2            3            4            5
# sex
# F      4578.193938  4546.432915  4602.921064  4549.200555  4591.999708
# M      4557.335897  4589.160781  4596.411698  4655.657044  4603.004990
#
#
# month            6
# sex
# F      4618.706399
# M      4593.426450

# %%
trial_table_1_part2=pd.pivot_table(trial_table_3, values=["Sales Value"], index=["sex"], columns="month", aggfunc='mean', fill_value=None, margins=False, dropna=True, margins_name='All', observed=False)

# %%
trial_table_1_part2
# Out:
#        Sales Value                                                      \
# month            1            2            3            4            5
# sex
# F      4578.193938  4546.432915  4602.921064  4549.200555  4591.999708
# M      4557.335897  4589.160781  4596.411698  4655.657044  4603.004990
#
#
# month            6
# sex
# F      4618.706399
# M      4593.426450

# %%
trial_table_1_part3=pd.pivot_table(trial_table_3, values=["Sales Value"], index=["sex"], columns="month", aggfunc='sum', fill_value=None, margins=False, dropna=True, margins_name='All', observed=False)

# %%
trial_table_1_part3 # total transaction value per gender per month
# Out:
#       Sales Value
# month           1         2         3         4         5         6
# sex
# F        31113406  31852309  31488583  31166573  31455198  31541146
# M        31409159  31968094  32455263  32254392  32285477  32163172

# %%
pip install dataframe_image
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import dataframe_image as dfi

# %%
final_table
# Out:
#       Stats
# month     1     2     3     4     5     6
# sex
# F      6796  7006  6841  6851  6850  6829
# M      6892  6966  7061  6928  7014  7002

# %%
dfi.export(final_table,"gender_final_table")
# Out:
# [0724/163529.989978:INFO:headless_shell.cc(660)] Written to file /var/folders/n1/vl98150x7gz4l5g4l74pjhqh0000gn/T/tmp58dnf2jx/temp.png.

# %%
trial_table_1_part2
# Out:
#        Sales Value                                                      \
# month            1            2            3            4            5
# sex
# F      4578.193938  4546.432915  4602.921064  4549.200555  4591.999708
# M      4557.335897  4589.160781  4596.411698  4655.657044  4603.004990
#
#
# month            6
# sex
# F      4618.706399
# M      4593.426450

# %%
dfi.export(trial_table_1_part2 ,"gender_mean")
# Out:
# [0724/163555.223723:INFO:headless_shell.cc(660)] Written to file /var/folders/n1/vl98150x7gz4l5g4l74pjhqh0000gn/T/tmpx7p7llzc/temp.png.

# %%
trial_table_1_part3
# Out:
#       Sales Value
# month           1         2         3         4         5         6
# sex
# F        31113406  31852309  31488583  31166573  31455198  31541146
# M        31409159  31968094  32455263  32254392  32285477  32163172

# %%
dfi.export(trial_table_1_part3,"gender_total")
# Out:
# [0724/163604.627509:INFO:headless_shell.cc(660)] Written to file /var/folders/n1/vl98150x7gz4l5g4l74pjhqh0000gn/T/tmpnnfx_s0g/temp.png.
